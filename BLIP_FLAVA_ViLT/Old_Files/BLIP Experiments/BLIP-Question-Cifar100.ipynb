# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import tqdm
from sklearn.metrics import accuracy_score
import numpy as np

from datasets import load_dataset, Image

from transformers import BlipForQuestionAnswering, BlipProcessor, BlipConfig, BlipModel

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class ImageDataset(torch.utils.data.Dataset):

    def __init__(self, image_files, text, processor, num_labels):
        self.image_files = image_files
        self.text = text
        self.processor = processor
        self.num_labels = num_labels

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        text = self.text
        image = self.image_files[idx]['img']
        label = self.image_files[idx]['fine_label']
        if image.mode != "RGB":
            image = image.convert("RGB")
        
        # encoding = self.processor(image, text, padding="max_length", truncation=True, return_tensors="pt")
        encoding = self.processor(image, text, return_tensors="pt")

        # remove batch dimension
        for k,v in encoding.items():
            encoding[k] = v.squeeze()
        targets = torch.zeros(self.num_labels)
        targets[label] = 1
        encoding["labels"] = targets

        return encoding

# %%
dataset = load_dataset('cifar100')
# Out:
# Found cached dataset cifar100 (/root/.cache/huggingface/datasets/cifar100/cifar100/1.0.0/f365c8b725c23e8f0f8d725c3641234d9331cd2f62919d1381d1baa5b3ba3142)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
label_list = dataset["train"].features["fine_label"].names
num_labels = len(label_list)

config = BlipConfig.from_pretrained("Salesforce/blip-vqa-base")
config.id2label = {str(i): label for i, label in enumerate(label_list)}
config.label2id = {label: str(i) for i, label in enumerate(label_list)}
config.num_labels = num_labels
config.max_length = 1
config.text_config.max_length = 1

processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")

train_dataset = ImageDataset(image_files=dataset["train"], text="What is this image?", processor=processor, num_labels=num_labels)
test_dataset = ImageDataset(image_files=dataset["test"], text="What is this image?", processor=processor, num_labels=num_labels)

# %%
model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base", config=config)
model = model.to(device)

# %%
def collate_fn(batch):
  input_ids = [item['input_ids'] for item in batch]
  pixel_values = [item['pixel_values'] for item in batch]
  attention_mask = [item['attention_mask'] for item in batch]
  # token_type_ids = [item['token_type_ids'] for item in batch]
  labels = [item['labels'] for item in batch]

  # create padded pixel values and corresponding pixel mask
  # encoding = processor.feature_extractor.pad_and_create_pixel_mask(pixel_values, return_tensors="pt")

  # create new batch
  batch = {}
  batch['input_ids'] = torch.stack(input_ids)
  batch['attention_mask'] = torch.stack(attention_mask)
  # batch['token_type_ids'] = torch.stack(token_type_ids)
  # batch['pixel_values'] = encoding['pixel_values']
  # batch['pixel_mask'] = encoding['pixel_mask']
  batch['pixel_values'] = torch.stack(pixel_values)
  batch['labels'] = torch.stack(labels)
  # batch['labels'] = torch.Tensor(labels).type(torch.LongTensor).unsqueeze(1)

  return batch

# %%
train_dataloader = DataLoader(train_dataset, collate_fn=collate_fn, batch_size=128, shuffle=True)
val_dataloader = DataLoader(test_dataset, collate_fn=collate_fn, batch_size=128, shuffle=True)

# %%
for name, param in model.named_parameters():
    param.requires_grad = False

# %%
model = model.to(device)

# %%
cls_model = nn.Sequential(
    nn.Linear(in_features=model.text_decoder.config.vocab_size, out_features=num_labels, bias=True)
)
cls_model = cls_model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cls_model.parameters(), lr=6e-4)
num_epochs = 30

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.25)

best_params = None
best_val_accuracy = -1

for epoch in range(1):
    model.train()
    total_loss = 0.0
    
    train_predictions = []
    train_labels_eval = []
    step = 0
    
    for batch in tqdm.tqdm(train_dataloader, desc=f"Epoch {epoch + 1}/{num_epochs}"):
        
        batch = {k:v.to(device) for k,v in batch.items()}

        optimizer.zero_grad()
        
        # import ipdb; ipdb.set_trace()
        outputs = model.generate(**batch)  # N,2
        outputs = outputs[:,1]
        outputs = nn.functional.one_hot(outputs, num_classes = model.text_decoder.config.vocab_size).type(torch.FloatTensor)
        outputs = outputs.to(device)
        labels = batch['labels']

        outputs_cls = cls_model(outputs)
        loss = criterion(outputs_cls, labels)
        loss.backward()
        
        optimizer.step()

        _, preds = torch.max(outputs_cls, 1)
        train_predictions.extend(preds.cpu().numpy())
        train_labels_eval.extend(labels.cpu().numpy())
        
        with open("BLIP-Question-C100.txt", 'a') as f:
            f.write(f"Batch: {step} --- Loss: {loss}\n")

        total_loss += loss
        step += 1
            
    scheduler.step()
    
    train_loss = total_loss / len(train_dataloader)
    
    # Evaluate the model on the validation set
    model.eval()
    val_predictions = []
    val_labels_eval = []
        
    with torch.no_grad():
        step = 0

        for batch in val_dataloader:
            batch = {k:v.to(device) for k,v in batch.items()}
            
            outputs = model.generate(**batch)
            outputs = outputs[:,1]
            outputs = nn.functional.one_hot(outputs, num_classes = model.text_decoder.config.vocab_size).type(torch.FloatTensor)
            outputs = outputs.to(device)

            outputs_cls = cls_model(outputs)
            _, preds = torch.max(outputs_cls, 1)
            labels = batch['labels']
            
            val_predictions.extend(preds.cpu().numpy())
            val_labels_eval.extend(labels.cpu().numpy())

            step += 1
    
    val_labels_idx = [np.argmax(tensor) for tensor in val_labels_eval]
    val_accuracy = accuracy_score(val_labels_idx, val_predictions)
    
    train_labels_idx = [np.argmax(tensor) for tensor in train_labels_eval]
    train_accuracy = accuracy_score(train_labels_idx, train_predictions)
    
    # print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}, Training Acc: {train_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}")
    to_write = f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}, Training Acc: {train_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}\n"
    with open("BLIP-Question-C100.txt", 'a') as f:
        f.write(to_write)
    # print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/30:   0%|          | 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (1) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   0%|          | 1/391 [00:05<32:48,  5.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 2/391 [00:08<25:04,  3.87s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 3/391 [00:11<22:25,  3.47s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 4/391 [00:14<21:13,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|▏         | 5/391 [00:17<20:29,  3.19s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 6/391 [00:20<20:19,  3.17s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 7/391 [00:23<20:35,  3.22s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 8/391 [00:26<20:17,  3.18s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 9/391 [00:29<19:58,  3.14s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 10/391 [00:32<19:36,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 11/391 [00:35<19:12,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 12/391 [00:38<19:06,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 13/391 [00:41<19:02,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▎         | 14/391 [00:44<18:56,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 15/391 [00:47<19:17,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 16/391 [00:50<19:20,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 17/391 [00:53<19:05,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▍         | 18/391 [00:56<18:50,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▍         | 19/391 [00:59<18:51,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▌         | 20/391 [01:02<18:34,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▌         | 21/391 [01:05<18:30,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 22/391 [01:08<18:28,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 23/391 [01:11<18:25,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 24/391 [01:14<18:26,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▋         | 25/391 [01:18<18:31,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 26/391 [01:21<18:50,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 27/391 [01:24<18:59,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 28/391 [01:27<18:44,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 29/391 [01:30<18:30,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 30/391 [01:33<18:19,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 31/391 [01:36<18:12,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 32/391 [01:39<18:05,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 33/391 [01:42<18:13,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▊         | 34/391 [01:45<18:10,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 35/391 [01:48<18:13,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 36/391 [01:51<18:04,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 37/391 [01:55<18:17,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|▉         | 38/391 [01:58<18:05,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|▉         | 39/391 [02:01<18:19,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|█         | 40/391 [02:04<18:05,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|█         | 41/391 [02:07<17:52,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█         | 42/391 [02:10<17:44,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█         | 43/391 [02:13<17:42,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█▏        | 44/391 [02:16<17:48,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 45/391 [02:19<17:36,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 46/391 [02:22<17:46,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 47/391 [02:25<17:45,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 48/391 [02:28<17:32,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 49/391 [02:31<17:25,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 50/391 [02:34<17:21,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 51/391 [02:37<17:08,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 52/391 [02:40<17:11,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▎        | 53/391 [02:44<17:31,  3.11s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 54/391 [02:47<17:18,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 55/391 [02:50<17:10,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 56/391 [02:53<17:10,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▍        | 57/391 [02:56<17:11,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▍        | 58/391 [02:59<16:59,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▌        | 59/391 [03:02<17:12,  3.11s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▌        | 60/391 [03:05<17:01,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 61/391 [03:08<16:49,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 62/391 [03:11<16:40,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 63/391 [03:14<16:34,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▋        | 64/391 [03:17<16:30,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 65/391 [03:20<16:30,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 66/391 [03:23<16:20,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 67/391 [03:26<16:12,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 68/391 [03:29<16:08,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 69/391 [03:32<16:07,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 70/391 [03:35<16:16,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 71/391 [03:38<16:13,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 72/391 [03:41<16:05,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▊        | 73/391 [03:44<16:08,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 74/391 [03:47<15:59,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 75/391 [03:50<15:50,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 76/391 [03:53<15:45,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|█▉        | 77/391 [03:56<15:43,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|█▉        | 78/391 [03:59<15:40,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|██        | 79/391 [04:03<16:00,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|██        | 80/391 [04:06<15:49,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 81/391 [04:09<15:43,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 82/391 [04:12<15:46,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 83/391 [04:15<15:49,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██▏       | 84/391 [04:18<15:54,  3.11s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 85/391 [04:21<15:42,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 86/391 [04:24<15:47,  3.11s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 87/391 [04:27<15:36,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 88/391 [04:30<15:33,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 89/391 [04:34<15:42,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 90/391 [04:37<15:38,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 91/391 [04:40<15:37,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▎       | 92/391 [04:43<15:21,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 93/391 [04:46<15:39,  3.15s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 94/391 [04:49<15:39,  3.16s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 95/391 [04:52<15:26,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▍       | 96/391 [04:55<15:13,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▍       | 97/391 [04:58<15:00,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▌       | 98/391 [05:02<15:03,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▌       | 99/391 [05:05<15:02,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 100/391 [05:08<14:56,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 101/391 [05:11<14:47,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 102/391 [05:14<14:39,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▋       | 103/391 [05:17<14:35,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 104/391 [05:20<14:34,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 105/391 [05:23<14:21,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 106/391 [05:26<14:15,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 107/391 [05:29<14:21,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 108/391 [05:32<14:39,  3.11s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 109/391 [05:35<14:43,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 110/391 [05:38<14:23,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 111/391 [05:41<14:13,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▊       | 112/391 [05:44<14:05,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 113/391 [05:47<14:08,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 114/391 [05:50<13:56,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 115/391 [05:53<13:57,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|██▉       | 116/391 [05:56<14:04,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|██▉       | 117/391 [05:59<13:57,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|███       | 118/391 [06:02<13:48,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|███       | 119/391 [06:06<13:46,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 120/391 [06:09<13:45,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 121/391 [06:12<13:41,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 122/391 [06:15<13:35,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███▏      | 123/391 [06:18<13:43,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 124/391 [06:21<13:35,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 125/391 [06:24<13:34,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 126/391 [06:27<13:27,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 127/391 [06:30<13:22,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 128/391 [06:33<13:15,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 129/391 [06:36<13:18,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 130/391 [06:39<13:12,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▎      | 131/391 [06:42<13:04,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 132/391 [06:45<13:02,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 133/391 [06:48<13:04,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 134/391 [06:51<13:09,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▍      | 135/391 [06:54<13:01,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▍      | 136/391 [06:57<12:55,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▌      | 137/391 [07:00<12:55,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▌      | 138/391 [07:03<12:44,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 139/391 [07:07<13:07,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 140/391 [07:10<13:03,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 141/391 [07:13<12:48,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▋      | 142/391 [07:16<12:41,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 143/391 [07:19<12:29,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 144/391 [07:22<12:25,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 145/391 [07:25<12:20,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 146/391 [07:28<12:22,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 147/391 [07:31<12:19,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 148/391 [07:34<12:17,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 149/391 [07:37<12:14,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 150/391 [07:40<12:27,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▊      | 151/391 [07:43<12:30,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 152/391 [07:46<12:26,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 153/391 [07:50<12:18,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 154/391 [07:53<12:07,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|███▉      | 155/391 [07:56<12:08,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|███▉      | 156/391 [07:59<12:08,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|████      | 157/391 [08:02<11:54,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|████      | 158/391 [08:05<11:48,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 159/391 [08:08<11:54,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 160/391 [08:11<11:46,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 161/391 [08:14<11:33,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████▏     | 162/391 [08:17<11:30,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 163/391 [08:20<11:36,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 164/391 [08:23<11:30,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 165/391 [08:26<11:32,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 166/391 [08:29<11:28,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 167/391 [08:32<11:16,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 168/391 [08:35<11:11,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 169/391 [08:38<11:07,  3.01s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 170/391 [08:41<10:56,  2.97s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▎     | 171/391 [08:44<10:46,  2.94s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▍     | 172/391 [08:47<10:52,  2.98s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▍     | 173/391 [08:50<10:51,  2.99s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▍     | 174/391 [08:53<11:07,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▍     | 175/391 [08:56<10:56,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▌     | 176/391 [08:59<10:53,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▌     | 177/391 [09:02<10:59,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 178/391 [09:05<10:50,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 179/391 [09:08<10:44,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 180/391 [09:11<10:42,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▋     | 181/391 [09:14<10:41,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 182/391 [09:18<10:42,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 183/391 [09:21<10:44,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 184/391 [09:24<10:31,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 185/391 [09:27<10:25,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 186/391 [09:30<10:19,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 187/391 [09:33<10:20,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 188/391 [09:36<10:25,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 189/391 [09:39<10:18,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▊     | 190/391 [09:42<10:11,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 191/391 [09:45<10:05,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 192/391 [09:48<10:00,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 193/391 [09:51<09:53,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|████▉     | 194/391 [09:54<09:49,  2.99s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|████▉     | 195/391 [09:57<09:44,  2.98s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|█████     | 196/391 [10:00<09:39,  2.97s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|█████     | 197/391 [10:03<09:41,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 198/391 [10:06<09:39,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 199/391 [10:09<09:40,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 200/391 [10:12<09:48,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████▏    | 201/391 [10:15<09:48,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 202/391 [10:18<09:39,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 203/391 [10:21<09:32,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 204/391 [10:24<09:38,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 205/391 [10:28<09:31,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 206/391 [10:31<09:31,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 207/391 [10:34<09:23,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 208/391 [10:37<09:20,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 209/391 [10:40<09:21,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▎    | 210/391 [10:43<09:16,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 211/391 [10:46<09:05,  3.03s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 212/391 [10:49<09:00,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 213/391 [10:52<08:54,  3.00s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▍    | 214/391 [10:55<08:55,  3.02s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▍    | 215/391 [10:58<09:02,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▌    | 216/391 [11:01<08:58,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▌    | 217/391 [11:04<08:54,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▌    | 218/391 [11:07<08:51,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▌    | 219/391 [11:10<08:45,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▋    | 220/391 [11:13<08:39,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 221/391 [11:16<08:39,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 222/391 [11:19<08:36,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 223/391 [11:23<08:36,  3.08s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 224/391 [11:26<08:43,  3.14s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  58%|█████▊    | 225/391 [11:29<08:37,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  58%|█████▊    | 226/391 [11:32<08:29,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# ...
# Epoch 1/30:  95%|█████████▌| 372/391 [19:00<00:59,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  95%|█████████▌| 373/391 [19:03<00:56,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 374/391 [19:06<00:52,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 375/391 [19:09<00:49,  3.07s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 376/391 [19:12<00:46,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▋| 377/391 [19:15<00:43,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 378/391 [19:19<00:40,  3.15s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 379/391 [19:22<00:37,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 380/391 [19:25<00:33,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 381/391 [19:28<00:30,  3.06s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 382/391 [19:31<00:27,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 383/391 [19:34<00:24,  3.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 384/391 [19:37<00:21,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 385/391 [19:40<00:18,  3.11s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▊| 386/391 [19:43<00:15,  3.10s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 387/391 [19:46<00:12,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 388/391 [19:49<00:09,  3.05s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 389/391 [19:52<00:06,  3.09s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30: 100%|█████████▉| 390/391 [19:56<00:03,  3.13s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30: 100%|██████████| 391/391 [19:58<00:00,  3.06s/it]
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
