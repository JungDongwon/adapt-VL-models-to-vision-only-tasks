# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import tqdm
from sklearn.metrics import accuracy_score
import numpy as np

from datasets import load_dataset, Image

from transformers import BlipForQuestionAnswering, BlipProcessor, BlipConfig, BlipModel

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class ImageDataset(torch.utils.data.Dataset):

    def __init__(self, image_files, text, processor, num_labels):
        self.image_files = image_files
        self.text = text
        self.processor = processor
        self.num_labels = num_labels

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        text = self.text
        image = self.image_files[idx]['img']
        label = self.image_files[idx]['label']
        if image.mode != "RGB":
            image = image.convert("RGB")
        
        # encoding = self.processor(image, text, padding="max_length", truncation=True, return_tensors="pt")
        encoding = self.processor(image, text, return_tensors="pt")

        # remove batch dimension
        for k,v in encoding.items():
            encoding[k] = v.squeeze()
        targets = torch.zeros(self.num_labels)
        targets[label] = 1
        encoding["labels"] = targets

        return encoding

# %%
dataset = load_dataset('cifar10')
# Out:
# Found cached dataset cifar10 (/root/.cache/huggingface/datasets/cifar10/plain_text/1.0.0/447d6ec4733dddd1ce3bb577c7166b986eaa4c538dcd9e805ba61f35674a9de4)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
label_list = dataset["train"].features["label"].names
num_labels = len(label_list)

config = BlipConfig.from_pretrained("Salesforce/blip-vqa-base")
config.id2label = {str(i): label for i, label in enumerate(label_list)}
config.label2id = {label: str(i) for i, label in enumerate(label_list)}
config.num_labels = num_labels
config.max_length = 1
config.text_config.max_length = 1

processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")

train_dataset = ImageDataset(image_files=dataset["train"], text="This is a classification prompt from the cifar10 dataset. Classify the images amongst the classes 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship' and 'truck'.", processor=processor, num_labels=num_labels)
test_dataset = ImageDataset(image_files=dataset["test"], text="This is a classification prompt from the cifar10 dataset. Classify the images amongst the classes 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship' and 'truck'.", processor=processor, num_labels=num_labels)

# %%
model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base", config=config)
model = model.to(device)

# %%
def collate_fn(batch):
  input_ids = [item['input_ids'] for item in batch]
  pixel_values = [item['pixel_values'] for item in batch]
  attention_mask = [item['attention_mask'] for item in batch]
  # token_type_ids = [item['token_type_ids'] for item in batch]
  labels = [item['labels'] for item in batch]

  # create padded pixel values and corresponding pixel mask
  # encoding = processor.feature_extractor.pad_and_create_pixel_mask(pixel_values, return_tensors="pt")

  # create new batch
  batch = {}
  batch['input_ids'] = torch.stack(input_ids)
  batch['attention_mask'] = torch.stack(attention_mask)
  # batch['token_type_ids'] = torch.stack(token_type_ids)
  # batch['pixel_values'] = encoding['pixel_values']
  # batch['pixel_mask'] = encoding['pixel_mask']
  batch['pixel_values'] = torch.stack(pixel_values)
  batch['labels'] = torch.stack(labels)
  # batch['labels'] = torch.Tensor(labels).type(torch.LongTensor).unsqueeze(1)

  return batch

# %%
train_dataloader = DataLoader(train_dataset, collate_fn=collate_fn, batch_size=128, shuffle=True)
val_dataloader = DataLoader(test_dataset, collate_fn=collate_fn, batch_size=128, shuffle=True)

# %%
for name, param in model.named_parameters():
    param.requires_grad = False

# %%
model = model.to(device)

# %%
cls_model = nn.Sequential(
    nn.Linear(in_features=model.text_decoder.config.vocab_size, out_features=num_labels, bias=True)
)
cls_model = cls_model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cls_model.parameters(), lr=6e-4)
num_epochs = 30

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.25)

best_params = None
best_val_accuracy = -1

for epoch in range(1):
    model.train()
    total_loss = 0.0
    
    train_predictions = []
    train_labels_eval = []
    step = 0
    
    for batch in tqdm.tqdm(train_dataloader, desc=f"Epoch {epoch + 1}/{num_epochs}"):
        batch = {k:v.to(device) for k,v in batch.items()}

        optimizer.zero_grad()
        
        # import ipdb; ipdb.set_trace()
        outputs = model.generate(**batch)  # N,2
        outputs = outputs[:,1]
        outputs = nn.functional.one_hot(outputs, num_classes = model.text_decoder.config.vocab_size).type(torch.FloatTensor)
        outputs = outputs.to(device)
        labels = batch['labels']

        outputs_cls = cls_model(outputs)
        loss = criterion(outputs_cls, labels)
        loss.backward()
        
        optimizer.step()

        _, preds = torch.max(outputs_cls, 1)
        train_predictions.extend(preds.cpu().numpy())
        train_labels_eval.extend(labels.cpu().numpy())
        
        to_write = f"Batch: {step} --- Loss: {loss}\n"
        with open("BLIP-Mahesh-C10.txt", 'a') as f:
            f.write(to_write)

        total_loss += loss
        step += 1
            
    scheduler.step()
    
    train_loss = total_loss / len(train_dataloader)
    
    # Evaluate the model on the validation set
    model.eval()
    val_predictions = []
    val_labels_eval = []
        
    with torch.no_grad():
        step = 0

        for batch in val_dataloader:
            batch = {k:v.to(device) for k,v in batch.items()}
            
            outputs = model.generate(**batch)
            outputs = outputs[:,1]
            outputs = nn.functional.one_hot(outputs, num_classes = model.text_decoder.config.vocab_size).type(torch.FloatTensor)
            outputs = outputs.to(device)

            outputs_cls = cls_model(outputs)
            _, preds = torch.max(outputs_cls, 1)
            labels = batch['labels']
            
            val_predictions.extend(preds.cpu().numpy())
            val_labels_eval.extend(labels.cpu().numpy())

            step += 1
    
    val_labels_idx = [np.argmax(tensor) for tensor in val_labels_eval]
    val_accuracy = accuracy_score(val_labels_idx, val_predictions)
    
    train_labels_idx = [np.argmax(tensor) for tensor in train_labels_eval]
    train_accuracy = accuracy_score(train_labels_idx, train_predictions)
    
    to_write = f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}, Training Acc: {train_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}\n"
    with open("BLIP-Mahesh-C10.txt", 'a') as f:
        f.write(to_write)
    # print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/30:   0%|          | 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (1) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   0%|          | 1/391 [00:09<1:01:09,  9.41s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 2/391 [00:13<39:33,  6.10s/it]  Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 3/391 [00:16<31:24,  4.86s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 4/391 [00:19<27:26,  4.25s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|▏         | 5/391 [00:23<24:42,  3.84s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 6/391 [00:26<23:40,  3.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 7/391 [00:29<22:54,  3.58s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 8/391 [00:33<22:30,  3.53s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 9/391 [00:36<21:58,  3.45s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 10/391 [00:39<22:03,  3.47s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 11/391 [00:43<21:32,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 12/391 [00:47<22:18,  3.53s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 13/391 [00:50<22:52,  3.63s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▎         | 14/391 [00:54<23:01,  3.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 15/391 [00:58<22:35,  3.61s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 16/391 [01:01<22:05,  3.53s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 17/391 [01:04<21:49,  3.50s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▍         | 18/391 [01:08<21:15,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▍         | 19/391 [01:11<20:55,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▌         | 20/391 [01:14<20:32,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▌         | 21/391 [01:17<20:26,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 22/391 [01:21<20:42,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 23/391 [01:24<20:22,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 24/391 [01:27<19:54,  3.25s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▋         | 25/391 [01:31<20:02,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 26/391 [01:34<19:53,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 27/391 [01:37<20:00,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 28/391 [01:41<20:15,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 29/391 [01:44<19:55,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 30/391 [01:47<20:07,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 31/391 [01:51<20:01,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 32/391 [01:54<19:34,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 33/391 [01:57<19:35,  3.28s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▊         | 34/391 [02:00<19:33,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 35/391 [02:03<19:15,  3.25s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 36/391 [02:07<19:28,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 37/391 [02:10<19:48,  3.36s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|▉         | 38/391 [02:14<19:27,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|▉         | 39/391 [02:17<19:16,  3.28s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|█         | 40/391 [02:20<19:16,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|█         | 41/391 [02:23<19:08,  3.28s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█         | 42/391 [02:27<18:56,  3.26s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█         | 43/391 [02:30<18:58,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█▏        | 44/391 [02:33<19:12,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 45/391 [02:37<19:26,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 46/391 [02:40<19:06,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 47/391 [02:43<19:07,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 48/391 [02:47<19:06,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 49/391 [02:50<18:58,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 50/391 [02:53<19:06,  3.36s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 51/391 [02:57<19:11,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 52/391 [03:00<18:48,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▎        | 53/391 [03:03<18:39,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 54/391 [03:07<18:48,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 55/391 [03:10<18:19,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 56/391 [03:13<18:19,  3.28s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▍        | 57/391 [03:17<18:19,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▍        | 58/391 [03:20<18:36,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▌        | 59/391 [03:23<18:17,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▌        | 60/391 [03:27<18:13,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 61/391 [03:30<18:08,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 62/391 [03:33<18:15,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 63/391 [03:36<17:58,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▋        | 64/391 [03:40<18:36,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 65/391 [03:44<18:49,  3.47s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 66/391 [03:47<18:30,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 67/391 [03:50<18:12,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 68/391 [03:54<17:56,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 69/391 [03:57<17:49,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 70/391 [04:00<17:41,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 71/391 [04:03<17:36,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 72/391 [04:07<17:28,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▊        | 73/391 [04:10<17:40,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 74/391 [04:13<17:28,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 75/391 [04:17<17:51,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 76/391 [04:20<17:52,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|█▉        | 77/391 [04:24<17:55,  3.43s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|█▉        | 78/391 [04:27<17:53,  3.43s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|██        | 79/391 [04:31<17:40,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|██        | 80/391 [04:34<17:21,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 81/391 [04:37<17:25,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 82/391 [04:40<17:10,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 83/391 [04:44<16:54,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██▏       | 84/391 [04:47<17:15,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 85/391 [04:50<17:00,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 86/391 [04:54<17:07,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 87/391 [04:57<17:14,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 88/391 [05:01<17:25,  3.45s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 89/391 [05:04<17:02,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 90/391 [05:08<17:00,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 91/391 [05:11<17:11,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▎       | 92/391 [05:15<17:02,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 93/391 [05:18<16:46,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 94/391 [05:21<16:35,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 95/391 [05:24<16:18,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▍       | 96/391 [05:28<16:15,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▍       | 97/391 [05:31<16:10,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▌       | 98/391 [05:34<16:31,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▌       | 99/391 [05:38<16:40,  3.43s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 100/391 [05:41<16:19,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 101/391 [05:45<16:08,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 102/391 [05:48<16:07,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▋       | 103/391 [05:51<16:03,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 104/391 [05:55<16:12,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 105/391 [05:58<16:21,  3.43s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 106/391 [06:02<16:21,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 107/391 [06:05<16:15,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 108/391 [06:09<16:14,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 109/391 [06:12<16:02,  3.41s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 110/391 [06:15<16:01,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 111/391 [06:19<16:09,  3.46s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▊       | 112/391 [06:22<15:54,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 113/391 [06:26<15:51,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 114/391 [06:29<15:44,  3.41s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 115/391 [06:32<15:38,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|██▉       | 116/391 [06:36<15:33,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|██▉       | 117/391 [06:39<15:03,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|███       | 118/391 [06:42<14:52,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|███       | 119/391 [06:45<14:57,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 120/391 [06:49<14:57,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 121/391 [06:52<14:51,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 122/391 [06:55<14:38,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███▏      | 123/391 [06:59<14:48,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 124/391 [07:02<14:49,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 125/391 [07:06<15:05,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 126/391 [07:09<15:09,  3.43s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 127/391 [07:12<14:52,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 128/391 [07:16<14:38,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 129/391 [07:19<14:57,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 130/391 [07:23<15:12,  3.49s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▎      | 131/391 [07:27<15:39,  3.61s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 132/391 [07:30<15:25,  3.57s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 133/391 [07:34<15:10,  3.53s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 134/391 [07:37<14:48,  3.46s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▍      | 135/391 [07:40<14:25,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▍      | 136/391 [07:44<14:22,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▌      | 137/391 [07:47<14:26,  3.41s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▌      | 138/391 [07:50<14:19,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 139/391 [07:54<14:07,  3.36s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 140/391 [07:57<13:57,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 141/391 [08:00<13:42,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▋      | 142/391 [08:03<13:38,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 143/391 [08:07<13:43,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 144/391 [08:10<13:44,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 145/391 [08:14<13:36,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 146/391 [08:17<13:30,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 147/391 [08:20<13:27,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 148/391 [08:23<13:16,  3.28s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 149/391 [08:27<13:07,  3.25s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 150/391 [08:30<13:00,  3.24s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▊      | 151/391 [08:33<13:05,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 152/391 [08:36<13:00,  3.26s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 153/391 [08:40<13:12,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 154/391 [08:43<13:36,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|███▉      | 155/391 [08:47<13:48,  3.51s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|███▉      | 156/391 [08:51<13:48,  3.53s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|████      | 157/391 [08:54<13:48,  3.54s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|████      | 158/391 [08:58<13:30,  3.48s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 159/391 [09:01<13:20,  3.45s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 160/391 [09:04<12:57,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 161/391 [09:07<12:47,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████▏     | 162/391 [09:11<12:44,  3.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 163/391 [09:14<12:45,  3.36s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 164/391 [09:18<12:48,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 165/391 [09:21<12:48,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 166/391 [09:24<12:42,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 167/391 [09:28<12:37,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 168/391 [09:31<12:35,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 169/391 [09:35<12:26,  3.36s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 170/391 [09:38<12:10,  3.30s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▎     | 171/391 [09:41<12:26,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▍     | 172/391 [09:45<12:23,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▍     | 173/391 [09:48<12:17,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▍     | 174/391 [09:52<12:49,  3.54s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▍     | 175/391 [09:56<12:45,  3.54s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▌     | 176/391 [09:59<12:37,  3.52s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▌     | 177/391 [10:02<12:28,  3.50s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 178/391 [10:06<12:20,  3.48s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 179/391 [10:09<12:21,  3.50s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 180/391 [10:13<12:37,  3.59s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▋     | 181/391 [10:16<12:10,  3.48s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 182/391 [10:20<12:02,  3.46s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 183/391 [10:23<11:55,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 184/391 [10:27<11:43,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 185/391 [10:30<11:45,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 186/391 [10:34<11:46,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 187/391 [10:37<11:33,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 188/391 [10:40<11:30,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 189/391 [10:44<11:21,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▊     | 190/391 [10:47<11:30,  3.44s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 191/391 [10:50<11:19,  3.40s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 192/391 [10:54<11:14,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 193/391 [10:57<11:11,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|████▉     | 194/391 [11:00<11:02,  3.36s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|████▉     | 195/391 [11:04<11:10,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|█████     | 196/391 [11:07<10:59,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|█████     | 197/391 [11:11<10:54,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 198/391 [11:14<10:53,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 199/391 [11:17<10:47,  3.37s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 200/391 [11:21<10:50,  3.41s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████▏    | 201/391 [11:24<10:33,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 202/391 [11:27<10:33,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 203/391 [11:31<10:29,  3.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 204/391 [11:34<10:23,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 205/391 [11:38<10:30,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 206/391 [11:41<10:15,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 207/391 [11:44<10:17,  3.36s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 208/391 [11:48<10:23,  3.41s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 209/391 [11:51<10:06,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▎    | 210/391 [11:54<10:11,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 211/391 [11:58<10:14,  3.41s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 212/391 [12:02<10:25,  3.49s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 213/391 [12:05<10:30,  3.54s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▍    | 214/391 [12:09<10:19,  3.50s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▍    | 215/391 [12:12<10:12,  3.48s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▌    | 216/391 [12:16<10:13,  3.51s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▌    | 217/391 [12:19<10:19,  3.56s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▌    | 218/391 [12:23<10:10,  3.53s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▌    | 219/391 [12:26<10:08,  3.54s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▋    | 220/391 [12:30<10:00,  3.51s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 221/391 [12:33<09:50,  3.48s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 222/391 [12:36<09:38,  3.42s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 223/391 [12:40<09:29,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 224/391 [12:43<09:26,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  58%|█████▊    | 225/391 [12:47<09:29,  3.43s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  58%|█████▊    | 226/391 [12:50<09:19,  3.39s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# ...
# Epoch 1/30:  95%|█████████▌| 372/391 [21:08<01:04,  3.38s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  95%|█████████▌| 373/391 [21:11<00:59,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 374/391 [21:14<00:56,  3.33s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 375/391 [21:18<00:53,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 376/391 [21:21<00:49,  3.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▋| 377/391 [21:24<00:46,  3.29s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 378/391 [21:28<00:42,  3.28s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 379/391 [21:31<00:39,  3.27s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 380/391 [21:34<00:36,  3.32s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 381/391 [21:38<00:35,  3.51s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 382/391 [21:44<00:38,  4.31s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 383/391 [21:51<00:39,  4.92s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 384/391 [21:57<00:37,  5.35s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 385/391 [22:03<00:34,  5.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▊| 386/391 [22:10<00:29,  5.94s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 387/391 [22:16<00:24,  6.04s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 388/391 [22:23<00:18,  6.18s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 389/391 [22:29<00:12,  6.25s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30: 100%|█████████▉| 390/391 [22:36<00:06,  6.34s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30: 100%|██████████| 391/391 [22:39<00:00,  3.48s/it]
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
