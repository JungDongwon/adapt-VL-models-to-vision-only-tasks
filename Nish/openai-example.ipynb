# %%
import openai
import os
from dotenv import load_dotenv

# %%
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
prompt = """
I will give you a list of reference words and phrases, followed by a list of candidate words and phrases. For each candidate, if the candidate is synonymous with an item from the reference list, please print the item. If not, please print the string “NONE”. Please print just the output, with no explanation. 

    Reference list: \"""
    cat
    dog
    big house
    plane
    \"""

    Example input: \"""
    home
    big house
    camel
    television
    feline
    \"""

    Example output: \"""
    big house
    NONE
    NONE
    cat
    \"""

    Input: \"""
    residence
    dogs
    TV
    aeroplane
    \"""
    """

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[{
      "role": "user",
      "content": prompt
  }],
  temperature=0.6
)

# %%
response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-79LOtCaJmrIbOz4jvnibgFqSaT80h at 0x7f4217317600> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "NONE\ndog\nNONE\nplane",
#         "role": "assistant"
#       }
#     }
#   ],
#   "created": 1682461571,
#   "id": "chatcmpl-79LOtCaJmrIbOz4jvnibgFqSaT80h",
#   "model": "gpt-3.5-turbo-0301",
#   "object": "chat.completion",
#   "usage": {
#     "completion_tokens": 7,
#     "prompt_tokens": 159,
#     "total_tokens": 166
#   }
# }

# %% [markdown]
# Cifar-100 test

# %%
prompt = """I will give you a list of reference words and phrases, followed by a list of candidate words and phrases. For each candidate, if the candidate is synonymous with an item from the reference list, please print the item. If not, please print the string “NONE”. Please print just the output, with no explanation. 

Reference list: \"""
worm
tank
crab
bee
orchid
skunk
woman
hamster
plate
table
house
possum
lobster
rocket
elephant
oak_tree
girl
whale
bridge
leopard
sea
sweet_pepper
wardrobe
crocodile
pickup_truck
chimpanzee
bus
clock
castle
bed
pear
snake
squirrel
bear
telephone
forest
trout
seal
flatfish
pine_tree
boy
cockroach
apple
aquarium_fish
skyscraper
lamp
porcupine
tulip
butterfly
couch
wolf
man
cattle
bottle
raccoon
dolphin
lizard
train
dinosaur
mushroom
caterpillar
poppy
sunflower
keyboard
bicycle
fox
plain
turtle
mountain
ray
cloud
kangaroo
baby
cup
beaver
shark
mouse
television
snail
spider
shrew
rose
motorcycle
camel
rabbit
otter
willow_tree
orange
streetcar
road
maple_tree
lion
palm_tree
tiger
beetle
lawn_mower
can
chair
bowl
tractor
\"""

Example input: \"""
TV
rooftop
ocean
ice
\"""

Example output: \"""
television
NONE
sea
NONE
\"""

Input: \"""
bears
flower
moon
bike
\"""
    """

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[{
      "role": "user",
      "content": prompt
  }],
  temperature=0.6
)

# %%
response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-79LbO59QG0Y5zYUvF8Vk5UDyLV9hm at 0x7f42141b1800> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "bear\nNONE\nNONE\nbicycle",
#         "role": "assistant"
#       }
#     }
#   ],
#   "created": 1682462346,
#   "id": "chatcmpl-79LbO59QG0Y5zYUvF8Vk5UDyLV9hm",
#   "model": "gpt-3.5-turbo-0301",
#   "object": "chat.completion",
#   "usage": {
#     "completion_tokens": 8,
#     "prompt_tokens": 398,
#     "total_tokens": 406
#   }
# }

# %%
response["choices"][0]["message"]["content"].split('\n')
# Out:
# ['bear', 'NONE', 'NONE', 'bicycle']

# %%
l = "\n".join(["one", "two", "car"])

wolf
leopard
ham
butterfly
shark
streetcar
keyboard
table
bus
table
lobster
cup
mouse
tank
tiger
sh
dinosaur
television
rose
poppy
oaktree
sun
oaktree
orchid
mouse
boy
bus
tiger
camel
spider
orange
cockach
otter
seal
skyscraper
leopard
telephone
raon
willowtree
chian
kangaroo
cup
bicycle
mushroom
sk
house
plain
snail
shark
pal
shark
plai
tiger
turtle
bowl
ham
plate
train
willowtree
pickuptruck
aquarium
lobster
cattle
crab
caterllar
poum
table
bear
otter
plai
chair
house
aquarium
cup
plain
beaver
mapletree
lizard
poppy
mapl
ray
mapletre
otter
girl
can
seal
ham
cattle
man
rocket
wolf
bed
bowl
pinetree
can
raon
wardrobe
tractor
road
pickuptruck
bus
turtl
dol
rocket
bridge
tractor
squirrel
lion
caterllar
seal
seal
lion
motorcycle
clock
can'ttell
bear
mapletree
flat
aqu
bee
house
tractor
bed
lawnmower
mush
turtle
willowtree
plate
palmtree
elephant
television
bear
poppy
oaktree
beetle
otter
table
raon
baby
bridge
bottle
cloud
chia
can
raon
man
orange
rocket
lawnmo
squirrel
bicycle
apple
bee
can
seal
bottle
chian
bridge
cattle
plat
girl
worm
apple
flat
poppy
willowtree
elephant
clock
lamp
beetle
raon
tiger
cou
trout
sk
girl
snail
tu
elephant
beetle
willowtr
lamp
man
rocket
pear
sweetpepper
bee
lobster
mapletree
can'ttell
rose
trout
otter
lawnmower
bicycle
leopard
clou
willow
cockach
lio
tiger
bowl
tu
rocket
sweetpepper
sweetpepper
telep
trout
spider
shark
house
shark
raon
beetle
camel
rabbit
poum
turtle
clock
pickuptruck
flat
lamp
leopard
ray
motorcycle
chair
"""

# %%
prompt
# Out:
# "I will give you a list of reference words and phrases, followed by a list of candidate words and phrases. For each candidate, if the candidate is synonymous with an item from the reference list, please print the item. If not, please print the string “NONE”. Please print just the output, with no explanation. \n\nReference list:\nworm\ntank\ncrab\nbee\norchid\nskunk\nwoman\nhamster\nplate\ntable\nhouse\npossum\nlobster\nrocket\nelephant\noak_tree\ngirl\nwhale\nbridge\nleopard\nsea\nsweet_pepper\nwardrobe\ncrocodile\npickup_truck\nchimpanzee\nbus\nclock\ncastle\nbed\npear\nsnake\nsquirrel\nbear\ntelephone\nforest\ntrout\nseal\nflatfish\npine_tree\nboy\ncockroach\napple\naquarium_fish\nskyscraper\nlamp\nporcupine\ntulip\nbutterfly\ncouch\nwolf\nman\ncattle\nbottle\nraccoon\ndolphin\nlizard\ntrain\ndinosaur\nmushroom\ncaterpillar\npoppy\nsunflower\nkeyboard\nbicycle\nfox\nplain\nturtle\nmountain\nray\ncloud\nkangaroo\nbaby\ncup\nbeaver\nshark\nmouse\ntelevision\nsnail\nspider\nshrew\nros
# ...

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[{
      "role": "user",
      "content": prompt
  }],
  temperature=0.6
)

# %%
responses = response["choices"][0]["message"]["content"].split('\n')

# %%
len(responses)
# Out:
# 403

# %%
responses
# Out:
# ['mountain',
#  'mountain',
#  'forest',
#  'woman',
#  'aquarium_fish',
#  'fox',
#  'bottle',
#  'dolphin',
#  'NONE',
#  'cockroach',
#  'shark',
#  'man',
#  'lamp',
#  'seal',
#  'worm',
#  'porcupine',
#  'whale',
#  'plain',
#  'cattle',
#  'beetle',
#  'cloud',
#  'tiger',
#  'apple',
#  'girl',
#  'kangaroo',
#  'bridge',
#  'lawn_mower',
#  'whale',
#  'bee',
#  'couch',
#  'streetcar',
#  'motorcycle',
#  'keyboard',
#  'clock',
#  'woman',
#  'kangaroo',
#  'orange',
#  'worm',
#  'bicycle',
#  'lobster',
#  'skyscraper',
#  'clock',
#  'plate',
#  'snake',
#  'sea',
#  'turtle',
#  'rose',
#  'plain',
#  'otter',
#  'can',
#  'sunflower',
#  'shrew',
#  'turtle',
#  'seal',
#  'table',
#  'bottle',
#  'lawn_mower',
#  'lobster',
#  'pine_tree',
#  'dinosaur',
#  'pine_tree',
#  'bus',
#  'beaver',
#  'boy',
#  'bed',
#  'rain',
#  'palm_tree',
#  'bear',
#  'dinosaur',
#  'beaver',
#  'cattle',
#  'cloud',
#  'girl',
#  'lamp',
#  'bottle',
#  'tank',
#  'boy',
# ...

# %%
orig_outputs = """mountain
mountain
forest
woman
aquari
fox
bottle
dolphin
squ
cockach
shark
man
lamp
seal
worm
porine
whale
plain
cattle
beetle
cloud
tiger
apple
girl
kangaroo
bridge
lawnmower
whale
bee
couch
streetcar
motorcycle
keyboard
clock
woman
kangaroo
orang
worm
bicycle
lobster
skyscraper
clock
plate
snake
sea
turtle
rose
plain
turtle
ott
can
sun
sh
tu
seal
table
bottle
lawnmower
lobster
pinetree
dinosaur
pinetree
bus
beaver
boy
bed
raon
palm
bear
din
beaver
cattle
cloud
girl
lamp
bottle
tank
boy
crocodile
mountain
cro
woman
rabbit
wardrobe
mouse
orang
sweetpepper
rose
ray
apple
house
girl
poppy
ray
sh
sea
bowl
bear
pickuptruck
sh
ray
telephone
whale
orchid
man
cockach
lobster
dinosaur
couch
cup
pickuptruck
palm
ham
mouse
dinosaur
boy
train
boy
bottle
cattle
crocodile
tractor
elephant
sk
poppy
kang
cat
telephone
willowtree
rabbit
telephone
rosebush
lamp
cate
train
kangaroo
poum
tracto
kangaroo
bicycle
mouse
rose
couch
moto
sweetpepper
sea
man
tulip
poppy
baby
plai
cattle
cattle
bee
rose
television
tiger
plate
snake
whale
telev
sweetpepper
pear
squir
plate
shark
dolphin
pickuptruck
chian
oaktree
otter
lion
camel
bed
chi
table
bear
whale
tra
clock
pinetree
squirrel
girl
mushroom
beetle
orange
ray
train
raon
beetle
tu
seal
bed
rabbit
pinetree
castle
snail
spider
porine
tractor
cro
lizard
cloc
lizard
road
porine
castle
bowl
man
tractor
beetle
dolphin
beaver
sky
cloud
pickuptruck
bottle
bed
bus
crab
turtle
kangaroo
cup
key
orange
snail
shark
orange
squirrel
clock
sweetpepper
raon
cloc
bear
bicycle
turtle
crocodil
bed
snake
boy
boy
porine
crocodile
ham
lawnmo
elephant
bottle
bicycle
bottl
skyscraper
chian
table
dinosaur
kangar
caterl
chair
trout
crab
fox
bed
castle
stree
girl
sh
leopard
oaktree
bottle
bridge
lion
sh
girl
leopard
bowl
orchid
wolf
leopard
ham
butterfly
shark
streetcar
keyboard
table
bus
table
lobster
cup
mouse
tank
tiger
sh
dinosaur
television
rose
poppy
oaktree
sun
oaktree
orchid
mouse
boy
bus
tiger
camel
spider
orange
cockach
otter
seal
skyscraper
leopard
telephone
raon
willowtree
chian
kangaroo
cup
bicycle
mushroom
sk
house
plain
snail
shark
pal
shark
plai
tiger
turtle
bowl
ham
plate
train
willowtree
pickuptruck
aquarium
lobster
cattle
crab
caterllar
poum
table
bear
otter
plai
chair
house
aquarium
cup
plain
beaver
mapletree
lizard
poppy
mapl
ray
mapletre
otter
girl
can
seal
ham
cattle
man
rocket
wolf
bed
bowl
pinetree
can
raon
wardrobe
tractor
road
pickuptruck
bus
turtl
dol
rocket
bridge
tractor
squirrel
lion
caterllar
seal
seal
lion
motorcycle
clock
can'ttell
bear
mapletree
flat
aqu
bee
house
tractor
bed
lawnmower
mush
turtle
willowtree
plate
palmtree
elephant
television
bear
poppy
oaktree
beetle
otter
table
raon
baby
bridge
bottle
cloud
chia
can
raon
man
orange
rocket
lawnmo
squirrel
bicycle
apple
bee
can
seal
bottle
chian
bridge
cattle
plat
girl
worm
apple
flat
poppy
willowtree
elephant
clock
lamp
beetle
raon
tiger
cou
trout
sk
girl
snail
tu
elephant
beetle
willowtr
lamp
man
rocket
pear
sweetpepper
bee
lobster
mapletree
can'ttell
rose
trout
otter
lawnmower
bicycle
leopard
clou
willow
cockach
lio
tiger
bowl
tu
rocket
sweetpepper
sweetpepper
telep
trout
spider
shark
house
shark
raon
beetle
camel
rabbit
poum
turtle
clock
pickuptruck
flat
lamp
leopard
ray
motorcycle
chair""".split('\n')

# %%
for i in range(len(responses)):
    print(f"{i}\t{orig_outputs[i]} -> {responses[i]}")
# Out:
# 0	mountain -> mountain
# 1	mountain -> mountain
# 2	forest -> forest
# 3	woman -> woman
# 4	aquari -> aquarium_fish
# 5	fox -> fox
# 6	bottle -> bottle
# 7	dolphin -> dolphin
# 8	squ -> NONE
# 9	cockach -> cockroach
# 10	shark -> shark
# 11	man -> man
# 12	lamp -> lamp
# 13	seal -> seal
# 14	worm -> worm
# 15	porine -> porcupine
# 16	whale -> whale
# 17	plain -> plain
# 18	cattle -> cattle
# 19	beetle -> beetle
# 20	cloud -> cloud
# 21	tiger -> tiger
# 22	apple -> apple
# 23	girl -> girl
# 24	kangaroo -> kangaroo
# 25	bridge -> bridge
# 26	lawnmower -> lawn_mower
# 27	whale -> whale
# 28	bee -> bee
# 29	couch -> couch
# 30	streetcar -> streetcar
# 31	motorcycle -> motorcycle
# 32	keyboard -> keyboard
# 33	clock -> clock
# 34	woman -> woman
# 35	kangaroo -> kangaroo
# 36	orang -> orange
# 37	worm -> worm
# 38	bicycle -> bicycle
# 39	lobster -> lobster
# 40	skyscraper -> skyscraper
# 41	clock -> clock
# 42	plate -> plate
# 43	snake -> snake
# 44	sea -> sea
# 45	turtle -> turtle
# ...
