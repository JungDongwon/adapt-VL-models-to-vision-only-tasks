# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import tqdm
from sklearn.metrics import accuracy_score
import numpy as np

from datasets import load_dataset, Image

from transformers import BlipForQuestionAnswering, BlipProcessor, BlipConfig, BlipModel

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class ImageDataset(torch.utils.data.Dataset):

    def __init__(self, image_files, text, processor, num_labels):
        self.image_files = image_files
        self.text = text
        self.processor = processor
        self.num_labels = num_labels

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        text = self.text
        image = self.image_files[idx]['img']
        label = self.image_files[idx]['label']
        if image.mode != "RGB":
            image = image.convert("RGB")
        
        # encoding = self.processor(image, text, padding="max_length", truncation=True, return_tensors="pt")
        encoding = self.processor(image, text, return_tensors="pt")

        # remove batch dimension
        for k,v in encoding.items():
            encoding[k] = v.squeeze()
        targets = torch.zeros(self.num_labels)
        targets[label] = 1
        encoding["labels"] = targets

        return encoding

# %%
dataset = load_dataset('cifar10')
# Out:
# Found cached dataset cifar10 (/root/.cache/huggingface/datasets/cifar10/plain_text/1.0.0/447d6ec4733dddd1ce3bb577c7166b986eaa4c538dcd9e805ba61f35674a9de4)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
label_list = dataset["train"].features["label"].names
num_labels = len(label_list)

config = BlipConfig.from_pretrained("Salesforce/blip-vqa-base")
config.id2label = {str(i): label for i, label in enumerate(label_list)}
config.label2id = {label: str(i) for i, label in enumerate(label_list)}
config.num_labels = num_labels
config.max_length = 1
config.text_config.max_length = 1

processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")

train_dataset = ImageDataset(image_files=dataset["train"], text="What is this image?", processor=processor, num_labels=num_labels)
test_dataset = ImageDataset(image_files=dataset["test"], text="What is this image?", processor=processor, num_labels=num_labels)

# %%
model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base", config=config)
model = model.to(device)

# %%
def collate_fn(batch):
  input_ids = [item['input_ids'] for item in batch]
  pixel_values = [item['pixel_values'] for item in batch]
  attention_mask = [item['attention_mask'] for item in batch]
  # token_type_ids = [item['token_type_ids'] for item in batch]
  labels = [item['labels'] for item in batch]

  # create padded pixel values and corresponding pixel mask
  # encoding = processor.feature_extractor.pad_and_create_pixel_mask(pixel_values, return_tensors="pt")

  # create new batch
  batch = {}
  batch['input_ids'] = torch.stack(input_ids)
  batch['attention_mask'] = torch.stack(attention_mask)
  # batch['token_type_ids'] = torch.stack(token_type_ids)
  # batch['pixel_values'] = encoding['pixel_values']
  # batch['pixel_mask'] = encoding['pixel_mask']
  batch['pixel_values'] = torch.stack(pixel_values)
  batch['labels'] = torch.stack(labels)
  # batch['labels'] = torch.Tensor(labels).type(torch.LongTensor).unsqueeze(1)

  return batch

# %%
train_dataloader = DataLoader(train_dataset, collate_fn=collate_fn, batch_size=128, shuffle=True)
val_dataloader = DataLoader(test_dataset, collate_fn=collate_fn, batch_size=128, shuffle=True)

# %%
for name, param in model.named_parameters():
    param.requires_grad = False

# %%
model = model.to(device)

# %%
cls_model = nn.Sequential(
    nn.Linear(in_features=model.text_decoder.config.vocab_size, out_features=num_labels, bias=True)
)
cls_model = cls_model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cls_model.parameters(), lr=6e-4)
num_epochs = 30

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.25)

best_params = None
best_val_accuracy = -1

for epoch in range(1):
    model.train()
    total_loss = 0.0
    
    train_predictions = []
    train_labels_eval = []
    step = 0
    
    for batch in tqdm.tqdm(train_dataloader, desc=f"Epoch {epoch + 1}/{num_epochs}"):
        batch = {k:v.to(device) for k,v in batch.items()}

        optimizer.zero_grad()
        
        # import ipdb; ipdb.set_trace()
        outputs = model.generate(**batch)  # N,2
        outputs = outputs[:,1]
        outputs = nn.functional.one_hot(outputs, num_classes = model.text_decoder.config.vocab_size).type(torch.FloatTensor)
        outputs = outputs.to(device)
        labels = batch['labels']

        outputs_cls = cls_model(outputs)
        loss = criterion(outputs_cls, labels)
        loss.backward()
        
        optimizer.step()

        _, preds = torch.max(outputs_cls, 1)
        train_predictions.extend(preds.cpu().numpy())
        train_labels_eval.extend(labels.cpu().numpy())

        total_loss += loss
        step += 1
            
    scheduler.step()
    
    train_loss = total_loss / len(train_dataloader)
    
    # Evaluate the model on the validation set
    model.eval()
    val_predictions = []
    val_labels_eval = []
        
    with torch.no_grad():
        step = 0

        for batch in val_dataloader:
            batch = {k:v.to(device) for k,v in batch.items()}
            
            outputs = model.generate(**batch)
            outputs = outputs[:,1]
            outputs = nn.functional.one_hot(outputs, num_classes = model.text_decoder.config.vocab_size).type(torch.FloatTensor)
            outputs = outputs.to(device)

            outputs_cls = cls_model(outputs)
            _, preds = torch.max(outputs_cls, 1)
            labels = batch['labels']
            
            val_predictions.extend(preds.cpu().numpy())
            val_labels_eval.extend(labels.cpu().numpy())

            step += 1
    
    val_labels_idx = [np.argmax(tensor) for tensor in val_labels_eval]
    val_accuracy = accuracy_score(val_labels_idx, val_predictions)
    
    train_labels_idx = [np.argmax(tensor) for tensor in train_labels_eval]
    train_accuracy = accuracy_score(train_labels_idx, train_predictions)
    
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}, Training Acc: {train_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}")
    # print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/30:   0%|          | 0/391 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (1) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   0%|          | 1/391 [00:04<29:36,  4.55s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 2/391 [00:07<22:12,  3.43s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 3/391 [00:09<20:11,  3.12s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|          | 4/391 [00:12<18:57,  2.94s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   1%|▏         | 5/391 [00:15<18:15,  2.84s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 6/391 [00:17<17:46,  2.77s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 7/391 [00:20<17:44,  2.77s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 8/391 [00:23<17:30,  2.74s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   2%|▏         | 9/391 [00:25<17:14,  2.71s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 10/391 [00:28<17:07,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 11/391 [00:31<16:57,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 12/391 [00:34<17:04,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   3%|▎         | 13/391 [00:36<17:00,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▎         | 14/391 [00:39<16:51,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 15/391 [00:42<16:49,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 16/391 [00:44<16:39,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   4%|▍         | 17/391 [00:47<16:38,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▍         | 18/391 [00:50<16:47,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▍         | 19/391 [00:52<16:38,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▌         | 20/391 [00:55<16:33,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   5%|▌         | 21/391 [00:58<16:34,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 22/391 [01:00<16:30,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 23/391 [01:03<16:23,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▌         | 24/391 [01:06<16:31,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   6%|▋         | 25/391 [01:08<16:28,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 26/391 [01:11<16:24,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 27/391 [01:14<16:26,  2.71s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 28/391 [01:17<16:20,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   7%|▋         | 29/391 [01:19<16:15,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 30/391 [01:22<16:07,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 31/391 [01:25<16:04,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 32/391 [01:27<16:00,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   8%|▊         | 33/391 [01:30<15:54,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▊         | 34/391 [01:33<15:52,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 35/391 [01:35<15:45,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 36/391 [01:38<15:45,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:   9%|▉         | 37/391 [01:41<15:39,  2.65s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|▉         | 38/391 [01:43<15:39,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|▉         | 39/391 [01:46<15:37,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|█         | 40/391 [01:49<15:32,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  10%|█         | 41/391 [01:51<15:30,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█         | 42/391 [01:54<15:30,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█         | 43/391 [01:57<15:26,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  11%|█▏        | 44/391 [01:59<15:25,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 45/391 [02:02<15:22,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 46/391 [02:05<15:19,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 47/391 [02:07<15:18,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  12%|█▏        | 48/391 [02:10<15:15,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 49/391 [02:13<15:14,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 50/391 [02:15<15:10,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 51/391 [02:18<15:09,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  13%|█▎        | 52/391 [02:21<15:06,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▎        | 53/391 [02:23<15:04,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 54/391 [02:26<15:01,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 55/391 [02:29<14:59,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  14%|█▍        | 56/391 [02:31<14:56,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▍        | 57/391 [02:34<14:50,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▍        | 58/391 [02:37<14:49,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▌        | 59/391 [02:39<14:47,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  15%|█▌        | 60/391 [02:42<14:41,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 61/391 [02:45<14:40,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 62/391 [02:47<14:39,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▌        | 63/391 [02:50<14:34,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  16%|█▋        | 64/391 [02:53<14:39,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 65/391 [02:55<14:32,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 66/391 [02:58<14:30,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 67/391 [03:01<14:28,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  17%|█▋        | 68/391 [03:03<14:28,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 69/391 [03:06<14:23,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 70/391 [03:09<14:18,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 71/391 [03:11<14:17,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  18%|█▊        | 72/391 [03:14<14:14,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▊        | 73/391 [03:17<14:13,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 74/391 [03:19<14:05,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 75/391 [03:22<14:04,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  19%|█▉        | 76/391 [03:25<14:04,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|█▉        | 77/391 [03:27<14:01,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|█▉        | 78/391 [03:30<14:01,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|██        | 79/391 [03:33<13:53,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  20%|██        | 80/391 [03:35<13:51,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 81/391 [03:38<13:50,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 82/391 [03:41<13:47,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██        | 83/391 [03:44<13:42,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  21%|██▏       | 84/391 [03:46<13:41,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 85/391 [03:49<13:40,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 86/391 [03:52<13:38,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  22%|██▏       | 87/391 [03:54<13:31,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 88/391 [03:57<13:38,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 89/391 [04:00<13:37,  2.71s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 90/391 [04:02<13:31,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  23%|██▎       | 91/391 [04:05<13:28,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▎       | 92/391 [04:08<13:20,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 93/391 [04:10<13:18,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 94/391 [04:13<13:17,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  24%|██▍       | 95/391 [04:16<13:14,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▍       | 96/391 [04:18<13:13,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▍       | 97/391 [04:21<13:10,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▌       | 98/391 [04:24<13:04,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  25%|██▌       | 99/391 [04:27<13:02,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 100/391 [04:29<13:00,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 101/391 [04:32<12:58,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▌       | 102/391 [04:35<12:56,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  26%|██▋       | 103/391 [04:37<12:55,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 104/391 [04:40<12:47,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 105/391 [04:43<12:46,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 106/391 [04:45<12:44,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  27%|██▋       | 107/391 [04:48<12:41,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 108/391 [04:51<12:34,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 109/391 [04:53<12:34,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 110/391 [04:56<12:31,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  28%|██▊       | 111/391 [04:59<12:31,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▊       | 112/391 [05:01<12:29,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 113/391 [05:04<12:25,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 114/391 [05:07<12:22,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  29%|██▉       | 115/391 [05:09<12:21,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|██▉       | 116/391 [05:12<12:18,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|██▉       | 117/391 [05:15<12:14,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|███       | 118/391 [05:17<12:14,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  30%|███       | 119/391 [05:20<12:07,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 120/391 [05:23<12:04,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 121/391 [05:25<12:03,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███       | 122/391 [05:28<12:01,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  31%|███▏      | 123/391 [05:31<11:54,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 124/391 [05:33<11:53,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 125/391 [05:36<11:51,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 126/391 [05:39<11:46,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  32%|███▏      | 127/391 [05:41<11:44,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 128/391 [05:44<11:44,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 129/391 [05:47<11:36,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  33%|███▎      | 130/391 [05:49<11:36,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▎      | 131/391 [05:52<11:33,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 132/391 [05:55<11:36,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 133/391 [05:58<11:33,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  34%|███▍      | 134/391 [06:00<11:31,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▍      | 135/391 [06:03<11:24,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▍      | 136/391 [06:06<11:22,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▌      | 137/391 [06:08<11:19,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  35%|███▌      | 138/391 [06:11<11:14,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 139/391 [06:14<11:13,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 140/391 [06:16<11:12,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▌      | 141/391 [06:19<11:08,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  36%|███▋      | 142/391 [06:22<11:04,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 143/391 [06:24<11:03,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 144/391 [06:27<11:01,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 145/391 [06:30<10:59,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  37%|███▋      | 146/391 [06:32<10:52,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 147/391 [06:35<10:52,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 148/391 [06:38<10:50,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 149/391 [06:40<10:44,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  38%|███▊      | 150/391 [06:43<10:43,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▊      | 151/391 [06:46<10:41,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 152/391 [06:48<10:41,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 153/391 [06:51<10:35,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  39%|███▉      | 154/391 [06:54<10:33,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|███▉      | 155/391 [06:56<10:31,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|███▉      | 156/391 [06:59<10:25,  2.66s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|████      | 157/391 [07:02<10:24,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  40%|████      | 158/391 [07:04<10:22,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 159/391 [07:07<10:20,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 160/391 [07:10<10:16,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████      | 161/391 [07:12<10:20,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  41%|████▏     | 162/391 [07:15<10:19,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 163/391 [07:18<10:16,  2.71s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 164/391 [07:21<10:13,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 165/391 [07:23<10:10,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  42%|████▏     | 166/391 [07:26<10:06,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 167/391 [07:29<10:02,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 168/391 [07:31<10:03,  2.71s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 169/391 [07:34<09:59,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  43%|████▎     | 170/391 [07:37<09:55,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▎     | 171/391 [07:39<09:52,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▍     | 172/391 [07:42<09:46,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  44%|████▍     | 173/391 [07:45<09:44,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▍     | 174/391 [07:48<09:46,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▍     | 175/391 [07:50<09:41,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▌     | 176/391 [07:53<09:38,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  45%|████▌     | 177/391 [07:56<09:34,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 178/391 [07:58<09:28,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 179/391 [08:01<09:26,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▌     | 180/391 [08:04<09:27,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  46%|████▋     | 181/391 [08:06<09:23,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 182/391 [08:09<09:20,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 183/391 [08:12<09:15,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 184/391 [08:14<09:13,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  47%|████▋     | 185/391 [08:17<09:11,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 186/391 [08:20<09:11,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 187/391 [08:22<09:08,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 188/391 [08:25<09:06,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  48%|████▊     | 189/391 [08:28<09:02,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▊     | 190/391 [08:30<09:01,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 191/391 [08:33<08:56,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 192/391 [08:36<08:58,  2.71s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  49%|████▉     | 193/391 [08:39<08:54,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|████▉     | 194/391 [08:41<08:51,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|████▉     | 195/391 [08:44<08:49,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|█████     | 196/391 [08:47<08:43,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  50%|█████     | 197/391 [08:49<08:40,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 198/391 [08:52<08:37,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 199/391 [08:55<08:36,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████     | 200/391 [08:57<08:34,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  51%|█████▏    | 201/391 [09:00<08:31,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 202/391 [09:03<08:27,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 203/391 [09:05<08:23,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 204/391 [09:08<08:21,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  52%|█████▏    | 205/391 [09:11<08:18,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 206/391 [09:13<08:14,  2.67s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 207/391 [09:16<08:12,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 208/391 [09:19<08:13,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  53%|█████▎    | 209/391 [09:22<08:08,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▎    | 210/391 [09:24<08:05,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 211/391 [09:27<08:03,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 212/391 [09:30<08:01,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  54%|█████▍    | 213/391 [09:32<07:59,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▍    | 214/391 [09:35<07:56,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▍    | 215/391 [09:38<07:54,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▌    | 216/391 [09:40<07:49,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  55%|█████▌    | 217/391 [09:43<07:50,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▌    | 218/391 [09:46<07:47,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▌    | 219/391 [09:48<07:41,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  56%|█████▋    | 220/391 [09:51<07:39,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 221/391 [09:54<07:37,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 222/391 [09:57<07:34,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 223/391 [09:59<07:31,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  57%|█████▋    | 224/391 [10:02<07:29,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  58%|█████▊    | 225/391 [10:05<07:27,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  58%|█████▊    | 226/391 [10:07<07:23,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# ...
# Epoch 1/30:  95%|█████████▌| 372/391 [16:40<00:51,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  95%|█████████▌| 373/391 [16:43<00:48,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 374/391 [16:45<00:45,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 375/391 [16:48<00:42,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▌| 376/391 [16:51<00:40,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  96%|█████████▋| 377/391 [16:53<00:37,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 378/391 [16:56<00:34,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 379/391 [16:59<00:32,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 380/391 [17:01<00:29,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  97%|█████████▋| 381/391 [17:04<00:26,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 382/391 [17:07<00:24,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 383/391 [17:10<00:21,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 384/391 [17:12<00:18,  2.68s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  98%|█████████▊| 385/391 [17:15<00:16,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▊| 386/391 [17:18<00:13,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 387/391 [17:20<00:10,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 388/391 [17:23<00:08,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30:  99%|█████████▉| 389/391 [17:26<00:05,  2.70s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30: 100%|█████████▉| 390/391 [17:28<00:02,  2.69s/it]Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30: 100%|██████████| 391/391 [17:30<00:00,  2.69s/it]
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1, but `max_length` is set to 1. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Epoch 1/30, Loss: 2.1659, Training Acc: 0.7526, Validation Accuracy: 0.7803
